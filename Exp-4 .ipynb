# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pandas import DataFrame, read_csv

#General Syntax to import a library but no functions
#import(library) as give us the library nickname/alias)
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sys #only to determine ptyhon version
import matplotlib  #only to determine matplotlib version

# %%
names=['Abhishek','Anandi','Siddarth','Parth','Parth','Deepak']
births=[968,50,180,578,577,973]
BabyDataset=list(zip(names,births))
BabyDataset
# Out:
# [('Abhishek', 968),
#  ('Anandi', 50),
#  ('Siddarth', 180),
#  ('Parth', 578),
#  ('Parth', 577),
#  ('Deepak', 973)]

# %%
df=pd.DataFrame(data=BabyDataset,columns=['Names','Births'])
df
# Out:
#       Names  Births
# 0  Abhishek     968
# 1    Anandi      50
# 2  Siddarth     180
# 3     Parth     578
# 4     Parth     577
# 5    Deepak     973

# %%
df=pd.read_csv("/content/drive/MyDrive/statewisetestingsamples.csv")
df.set_index("TotalSamples")
df
# Out:
#             Date                        State  TotalSamples  Negative  \
# 0     17/04/2020  Andaman and Nicobar Islands          1403    1210.0
# 1     24/04/2020  Andaman and Nicobar Islands          2679       NaN
# 2     27/04/2020  Andaman and Nicobar Islands          2848       NaN
# 3     01/05/2020  Andaman and Nicobar Islands          3754       NaN
# 4     16/05/2020  Andaman and Nicobar Islands          6677       NaN
# ...          ...                          ...           ...       ...
# 1770  01/06/2020                  West Bengal        213231       NaN
# 1771  02/06/2020                  West Bengal        222726       NaN
# 1772  03/06/2020                  West Bengal        232225       NaN
# 1773  04/06/2020                  West Bengal        241831       NaN
# 1774  05/06/2020                  West Bengal        251517       NaN
#
#       Positive
# 0         12.0
# 1         27.0
# 2         33.0
# 3         33.0
# 4         33.0
# ...        ...
# ...

# %%
df.dtypes
# Out:
# Date             object
# State            object
# TotalSamples      int64
# Negative        float64
# Positive        float64
# dtype: object

# %%
df.sort_values(['Positive'], ascending=False)
# Out:
#             Date        State  TotalSamples  Negative  Positive
# 1049  06/06/2020  Maharashtra        538009  451764.0   80229.0
# 1048  05/06/2020  Maharashtra        524002  440445.0   77793.0
# 1047  04/06/2020  Maharashtra        511136  430100.0   74860.0
# 1046  03/06/2020  Maharashtra        498577  420644.0   72300.0
# 1045  02/06/2020  Maharashtra        484784  409178.0   70013.0
# ...          ...          ...           ...       ...       ...
# 1715  06/04/2020  West Bengal          1301       NaN       NaN
# 1716  07/04/2020  West Bengal          1487       NaN       NaN
# 1717  09/04/2020  West Bengal          1889       NaN       NaN
# 1718  10/04/2020  West Bengal          2095       NaN       NaN
# 1739  01/05/2020  West Bengal         18566       NaN       NaN
#
# [1775 rows x 5 columns]

# %%
df.loc[56]
# Out:
# Date                30/05/2020
# State           Andhra Pradesh
# TotalSamples            363378
# Negative              359917.0
# Positive                2944.0
# Name: 56, dtype: object

# %%
df.rank()
# Out:
#         Date   State  TotalSamples  Negative  Positive
# 0      927.5     3.5         239.0     150.0     301.0
# 1     1346.0     3.5         340.0       NaN     382.5
# 2     1520.5     3.5         350.0       NaN     419.5
# 3       18.5     3.5         417.0       NaN     419.5
# 4      897.5     3.5         579.5       NaN     419.5
# ...      ...     ...           ...       ...       ...
# 1770    48.5  1744.5        1631.0       NaN    1576.0
# 1771   116.0  1744.5        1643.0       NaN    1584.0
# 1772   181.5  1744.5        1653.0       NaN    1594.0
# 1773   247.0  1744.5        1664.0       NaN    1603.0
# 1774   318.5  1744.5        1671.0       NaN    1614.0
#
# [1775 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Date'].plot(kind='hist', bins=20, title='Date')
# ...

# %%
df.head()
# Out:
#          Date                        State  TotalSamples  Negative  Positive
# 0  17/04/2020  Andaman and Nicobar Islands          1403    1210.0      12.0
# 1  24/04/2020  Andaman and Nicobar Islands          2679       NaN      27.0
# 2  27/04/2020  Andaman and Nicobar Islands          2848       NaN      33.0
# 3  01/05/2020  Andaman and Nicobar Islands          3754       NaN      33.0
# 4  16/05/2020  Andaman and Nicobar Islands          6677       NaN      33.0

# %%
gb=df.groupby("State")
gb

# %%
gb.get_group('Bihar')
# Out:
#            Date  State  TotalSamples  Negative  Positive
# 157  05/04/2020  Bihar          3037    2299.0      32.0
# 158  05/04/2020  Bihar          3037    2299.0      32.0
# 159  08/04/2020  Bihar          4596       NaN      38.0
# 160  09/04/2020  Bihar          4991       NaN      43.0
# 161  10/04/2020  Bihar          5457       NaN      60.0
# 162  11/04/2020  Bihar          6250       NaN      61.0
# 163  12/04/2020  Bihar          6703       NaN      64.0
# 164  13/04/2020  Bihar          7263       NaN      65.0
# 165  14/04/2020  Bihar          7727       NaN      62.0
# 166  15/04/2020  Bihar          8263       NaN      66.0
# 167  16/04/2020  Bihar          8846       NaN      72.0
# 168  17/04/2020  Bihar          9486       NaN      83.0
# 169  18/04/2020  Bihar         10130       NaN      85.0
# 170  19/04/2020  Bihar         10745       NaN      92.0
# 171  20/04/2020  Bihar         11319       NaN      96.0
# ...

# %% [markdown]
# **convert csv in dataframe , print nuber rows and col in this data set , sort on the blood sugar**

# %%
df1=pd.read_csv("/content/drive/MyDrive/diabetes.csv")
df1.set_index("Glucose")
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
print('Number of rows:', df1.shape[0])
print('Number of columns:', df1.shape[1])
# Out:
# Number of rows: 768
# Number of columns: 9

# %%
df1_sorted = df1.sort_values(by='Glucose')
 #Print the sorted data
print(df1_sorted)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 502            6        0             68             41        0  39.0
# 349            5        0             80             32        0  41.0
# 342            1        0             68             35        0  32.0
# 182            1        0             74             20       23  27.7
# ..           ...      ...            ...            ...      ...   ...
# 228            4      197             70             39      744  36.7
# 408            8      197             74              0        0  25.9
# 8              2      197             70             45      543  30.5
# 561            0      198             66             32      274  41.3
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# ...

# %%
df1.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
print(df.tail(20))
# Out:
#             Date        State  TotalSamples  Negative  Positive
# 1755  17/05/2020  West Bengal         85956       NaN    2677.0
# 1756  18/05/2020  West Bengal         93570       NaN    2825.0
# 1757  19/05/2020  West Bengal        102282       NaN    2961.0
# 1758  20/05/2020  West Bengal        111002       NaN    3103.0
# 1759  21/05/2020  West Bengal        115244       NaN    3197.0
# 1760  22/05/2020  West Bengal        120599       NaN    3332.0
# 1761  23/05/2020  West Bengal        129608       NaN    3459.0
# 1762  24/05/2020  West Bengal        138824       NaN    3667.0
# 1763  25/05/2020  West Bengal        148049       NaN    3816.0
# 1764  26/05/2020  West Bengal        157277       NaN    4009.0
# 1765  27/05/2020  West Bengal        166513       NaN    4192.0
# 1766  28/05/2020  West Bengal        175769       NaN    4536.0
# 1767  29/05/2020  West Bengal        185051       NaN    4813.0
# 1768  30/05/2020  West Bengal        194397       NaN    5130.0
# ...

# %%
df.isnull()
# Out:
#        Date  State  TotalSamples  Negative  Positive
# 0     False  False         False     False     False
# 1     False  False         False      True     False
# 2     False  False         False      True     False
# 3     False  False         False      True     False
# 4     False  False         False      True     False
# ...     ...    ...           ...       ...       ...
# 1770  False  False         False      True     False
# 1771  False  False         False      True     False
# 1772  False  False         False      True     False
# 1773  False  False         False      True     False
# 1774  False  False         False      True     False
#
# [1775 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Date              0
# State             0
# TotalSamples      0
# Negative        382
# Positive          8
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1775 entries, 0 to 1774
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1775 non-null   object
#  1   State         1775 non-null   object
#  2   TotalSamples  1775 non-null   int64
#  3   Negative      1393 non-null   float64
#  4   Positive      1767 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 69.5+ KB

# %%
df.describe()
# Out:
#         TotalSamples       Negative      Positive
# count    1775.000000    1393.000000   1767.000000
# mean    62590.342535   61583.492462   2551.825127
# std     97161.457351   97730.924184   7220.357070
# min        58.000000       0.000000      0.000000
# 25%      4188.500000    4199.000000     36.000000
# 50%     19063.000000   17662.000000    331.000000
# 75%     78021.000000   72494.000000   1938.000000
# max    576695.000000  550643.000000  80229.000000

# %%
cor=df1.corr()
num_df=df1.select_dtypes(exclude="object")
corr_num=num_df.corr()
sns.heatmap(corr_num, annot=True, cmap="RdBu_r")
plt.title("Correlation Matrix", fontsize=16)
plt.show()

# %%
cor=df.corr()
num_df=df.select_dtypes(exclude="object")
corr_num=num_df.corr()
sns.heatmap(corr_num, annot=True, cmap="RdBu_r")
plt.title("Correlation Matrix", fontsize=16)
plt.show()
# Out:
# <ipython-input-29-ed1689f4e636>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
